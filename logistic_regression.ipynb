# %% [markdown]
# <a href="https://colab.research.google.com/github/edoardo2496/data_science_portfolio/blob/main/logistic_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ####*paths & dataset import*

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler
import kagglehub

path = kagglehub.dataset_download("pavansubhasht/ibm-hr-analytics-attrition-dataset") # scarico il dataset da kaggle
dataset_hr = pd.read_csv(path + "/WA_Fn-UseC_-HR-Employee-Attrition.csv") # lo leggo come csv

print(dataset_hr['OverTime'].head())
print(dataset_hr.info())

# %% [markdown]
# ####*data_preparation*

# %%
dataset_hr['is_quit'] = np.where(dataset_hr['Attrition'] == 'Yes',1,0) # codifico in maniera binaria il campo Attrition
